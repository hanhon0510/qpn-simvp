# %%
import torch
from torch.utils.data import DataLoader
from dataset import TIFDataset
# from models import SimVP
from simvp import SimVP
import torch.optim as optim
import os
# import matplotlib.pyplot as plt

# %%
root_dir = r'D:\Workspace\Projects\qpn-simvp\data\DATA_SV\Precipitation\Radar\2019\10'
save_dir = r'D:\Workspace\Projects\qpn-simvp\simvp\pth'  
os.makedirs(save_dir, exist_ok=True)
print(f"Using root_dir: {root_dir}")
print(f"Does root_dir exist? {'Yes' if os.path.exists(root_dir) else 'No'}")

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

dataset = TIFDataset(root_dir)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)  # Batch size of 1 given the sequence nature

shape_in = (12, 1, 304, 304)  # Adjust accordingly
model = SimVP(shape_in, hid_S=16, hid_T=256, N_S=4, N_T=8, incep_ker=[3,5,7,11], groups=8)
model = model.to(device)

criterion = torch.nn.MSELoss()  # Example: MSE loss for prediction tasks
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# Using root_dir: D:\Workspace\Projects\qpn-simvp\data\DATA_SV\Precipitation\Radar\2019\10
# Does root_dir exist? Yes
# Using device: cuda
# Looking in root_dir: D:\Workspace\Projects\qpn-simvp\data\DATA_SV\Precipitation\Radar\2019\10

# %%
# Training loop
num_epochs = 10  # Define the number of epochs you want to train for
time_step_buffer = []  # Initialize the buffer outside the epoch loop
sequence_length = 12  # Define the desired sequence length

def check_nan(tensor, name="Tensor"):
  """Utility function to check for NaN values in a tensor."""
  isnan = torch.isnan(tensor).any().item()
  print(f"{name} contains NaN: {isnan}")
  return isnan

for epoch in range(num_epochs):
    for batch_idx, inputs in enumerate(dataloader):
        # Ensure inputs are on the correct device
        inputs = inputs.to(device)

        if check_nan(inputs, "Inputs"):
          print("NaN detected in inputs, skipping this batch.")
          continue

        # Accumulate time steps in the buffer
        time_step_buffer.append(inputs)

        # Proceed only if we have accumulated enough time steps
        if len(time_step_buffer) == sequence_length:
            # Stack the accumulated time steps along a new dimension
            sequence_input = torch.stack(time_step_buffer, dim=1)  # Resulting shape should be [1, sequence_length, 1, 90, 250]
            sequence_input = sequence_input.squeeze(2)  # Adjust the squeezing depending on your actual data shape
            
            # Ensure the sequence is on the correct device
            sequence_input = sequence_input.to(device)

            # Simulate targets for now; adjust as necessary for your application
            # Here, just for the sake of having a target of matching dimensions
            targets = torch.randn_like(sequence_input)  # Creating dummy targets of the same shape as sequence_input
            targets = targets.to(device)

            optimizer.zero_grad()

            # print(f"Input shape before model: {sequence_input.shape}")  # Ensure this matches your model's expected input
            sequence_input = sequence_input.unsqueeze(2)  # Add a singleton channel dimension
            # print(f"Adjusted input shape before model: {sequence_input.shape}")
            outputs = model(sequence_input)

            if check_nan(outputs, "Outputs"):
              print("NaN detected in model outputs, skipping this batch.")
              continue

            loss = criterion(outputs, targets)  # Compute loss
            if check_nan(loss, "Loss"):
              print("NaN detected in loss, skipping this batch.")
              continue
            loss.backward()  # Backpropagation
            optimizer.step()  # Update model parameters

            # Clear the buffer for the next sequence
            time_step_buffer.clear()

            if batch_idx % 10 == 0:  # Print every 10 batches
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(dataloader)}], Loss: {loss.item()}')

    # Save the model after each epoch
    model_save_path = os.path.join(save_dir, f'model_epoch_{epoch}.pth')
    torch.save(model.state_dict(), model_save_path)
    print(f"Model saved for epoch {epoch} at {model_save_path}")
    # torch.save(model.state_dict(), f'model_epoch_{epoch}.pth')
    # print(f'Model saved for epoch {epoch}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6512\964138278.py in ?()
#       9   print(f"{name} contains NaN: {isnan}")
#      10   return isnan
#      11
#      12 for epoch in range(num_epochs):
# ---> 13     for batch_idx, inputs in enumerate(dataloader):
#      14         # Ensure inputs are on the correct device
#      15         inputs = inputs.to(device)
#      16
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\torch\utils\data\dataloader.py in ?(self)
#     627         with torch.autograd.profiler.record_function(self._profile_name):
#     628             if self._sampler_iter is None:
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#     634                     self._IterableDataset_len_called is not None and \
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\torch\utils\data\dataloader.py in ?(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#     678         return data
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\torch\utils\data\_utils\fetch.py in ?(self, possibly_batched_index)
#      47         if self.auto_collation:
#      48             if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#      54         return self.collate_fn(data)
#
# d:\Workspace\Projects\qpn-simvp\simvp\dataset.py in ?(self, idx)
#      22     def __getitem__(self, idx):
#      23         file_path = self.file_paths[idx]
# ---> 24         image = imread(file_path)
#      25
#      26         # Assuming the image is single-channel; add channel dimension if it's not present
#      27         if image.ndim == 2:
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\tifffile\tifffile.py in ?(***failed resolving arguments***)
#    1270                     )
#    1271                     if selection is None:
#    1272                         return store
#    1273                     return zarr_selection(store, selection, out=out)
# -> 1274                 return tif.asarray(
#    1275                     key=key,
#    1276                     series=series,
#    1277                     level=level,
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\tifffile\tifffile.py in ?(self, key, series, level, squeeze, out, maxworkers, buffersize)
#    4509         elif len(pages) == 1:
#    4510             page0 = pages[0]
#    4511             if page0 is None:
#    4512                 raise ValueError('page is None')
# -> 4513             result = page0.asarray(
#    4514                 out=out, maxworkers=maxworkers, buffersize=buffersize
#    4515             )
#    4516         else:
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\tifffile\tifffile.py in ?(self, out, squeeze, lock, maxworkers, buffersize)
#    9305                     ]
#    9306                 # except IndexError:
#    9307                 #     pass  # corrupted file, for example, with too many strips
#    9308
# -> 9309             for _ in self.segments(
#    9310                 func=func,
#    9311                 lock=lock,
#    9312                 maxworkers=maxworkers,
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\tifffile\tifffile.py in ?(self, lock, maxworkers, func, sort, buffersize, _fullsize)
#    9101                 sort=sort,
#    9102                 buffersize=buffersize,
#    9103                 flat=True,
#    9104             ):
# -> 9105                 yield decode(segment)
#    9106         else:
#    9107             # reduce memory overhead by processing chunks of up to
#    9108             # buffersize of segments because ThreadPoolExecutor.map is not
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\tifffile\tifffile.py in ?(args, decodeargs, decode)
#    9091             def decode(args, decodeargs=decodeargs, decode=keyframe.decode):
# -> 9092                 return func(decode(*args, **decodeargs))  # type: ignore
#
# d:\anaconda3\envs\SimVP\Lib\site-packages\tifffile\tifffile.py in ?(exc, *args, **kwargs)
#    8515             def decode_raise_compression(*args, exc=str(exc)[1:-1], **kwargs):
# -> 8516                 raise ValueError(f'{exc}')
#
# ValueError: <COMPRESSION.LZW: 5> requires the 'imagecodecs' package

# %%
model.load_state_dict(torch.load('pth\model_epoch_9.pth', map_location=torch.device('cpu')))
model.eval()
val_dataset = TIFDataset(val_root_dir)  # Ensure this class is defined to handle your data format
val_dataloader = DataLoader(val_dataset, batch_size=1, shuffle=False)  # Shuffle usually False for validation

# Evaluate the model on the validation dataset
val_losses = []
with torch.no_grad():  # Disables gradient calculation
    for val_inputs in val_dataloader:
        val_inputs = val_inputs.to(device)  # Move data to the correct device

        # Simulate the targets for validation set; in practice, you should have true targets
        # Ensure that the shape of val_targets matches model's output expected shape
        val_targets = torch.randn_like(val_inputs)

        # Forward pass
        val_outputs = model(val_inputs)

        # Calculate the loss
        val_loss = torch.sqrt(criterion(val_outputs, val_targets))  # Using RMSE as per your example
        val_losses.append(val_loss.item())

# Calculate average validation loss
avg_val_loss = sum(val_losses) / len(val_losses)
print(f'Average validation RMSE loss: {avg_val_loss}')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9764\2308769487.py:1: SyntaxWarning: invalid escape sequence '\m'
#   model.load_state_dict(torch.load('pth\model_epoch_9.pth', map_location=torch.device('cpu')))
# Looking in root_dir: D:\Workspace\Projects\qpn-simvp\data\DATA_SV\Precipitation\Radar\2020\10
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9764\2308769487.py:1: SyntaxWarning: invalid escape sequence '\m'
#   model.load_state_dict(torch.load('pth\model_epoch_9.pth', map_location=torch.device('cpu')))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       6 val_dataset = TIFDataset(val_root_dir)
#       8 y = DataLoader(val_dataset, batch_size=1, shuffle=True)  # Batch size of 1 given the sequence nature
# ---> 10 loss = torch.sqrt(criterion(x, y))
#      11 loss.backward()
#      12 x.grad
#
# File d:\anaconda3\envs\SimVP\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\SimVP\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\anaconda3\envs\SimVP\Lib\site-packages\torch\nn\modules\loss.py:535, in MSELoss.forward(self, input, target)
#     534 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 535     return F.mse_loss(input, target, reduction=self.reduction)
#
# File d:\anaconda3\envs\SimVP\Lib\site-packages\torch\nn\functional.py:3328, in mse_loss(input, target, size_average, reduce, reduction)
#    3324 if has_torch_function_variadic(input, target):
#    3325     return handle_torch_function(
#    3326         mse_loss, (input, target), input, target, size_average=size_average, reduce=reduce, reduction=reduction
#    3327     )
# -> 3328 if not (target.size() == input.size()):
#    3329     warnings.warn(
#    3330         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}). "
#    3331         "This will likely lead to incorrect results due to broadcasting. "
#    3332         "Please ensure they have the same size.",
#    3333         stacklevel=2,
#    3334     )
#    3335 if size_average is not None or reduce is not None:
#
# AttributeError: 'DataLoader' object has no attribute 'size'
